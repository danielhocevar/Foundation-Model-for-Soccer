# %%
import json
with open('action_types.json', 'r') as f:
    action_types = json.load(f)

# %%
import pandas as pd
from preprocess_data import *

df = (
    pd.read_csv("WSL_actions.csv", index_col = 0)
    .pipe(add_coordinate_bins, n_bins_x = 10, n_bins_y = 10)
    .pipe(add_team_as_dummy)
    .pipe(get_action_type_names, action_types)
    .pipe(get_action_tokens)
    .assign(
        match_id = lambda d: d.groupby(['game_id']).ngroup(),
        action_token = lambda d: pd.Categorical(d.action_token)
    )
    [['match_id', 'action_token']]
)

vocab = df['action_token'].cat.categories

df
# Out:
#       match_id        action_token
# 0          315       True,pass,4,4
# 1          315   True,receival,4,5
# 2          315    True,dribble,4,5
# 3          315       True,pass,5,5
# 4          315   True,receival,6,4
# ...        ...                 ...
# 3130        82  False,receival,8,0
# 3131        82   False,dribble,8,0
# 3132        82    False,tackle,9,0
# 3133        82   False,dribble,9,0
# 3134        82      False,pass,8,1
#
# [939920 rows x 2 columns]

# %%
from numpy.random import choice, seed

seed(42)
train_groups = choice(df['match_id'].unique(), int(0.8 * df['match_id'].nunique()), replace = False)
validation_candidates = list(set(df['match_id'].unique()) - set(train_groups))
val_groups = choice(validation_candidates, int(len(validation_candidates) * 0.5), replace = False)
test_groups = np.array(list(set(validation_candidates) - set(val_groups)))
train_groups[:5]
# Out:
# array([ 96, 313,  43, 251, 281], dtype=int64)

# %%
counts = pd.read_csv("transition_counts.csv", index_col = 0)
counts_smoothed = counts + 1
probs = counts_smoothed / counts_smoothed.sum()
probs
# Out:
#                       False,bad_touch,0,0  False,bad_touch,0,1  \
# row_0
# False,bad_touch,0,0              0.000345             0.000345
# False,bad_touch,0,1              0.000345             0.000345
# False,bad_touch,0,2              0.000345             0.000345
# False,bad_touch,0,3              0.000345             0.000345
# False,bad_touch,0,4              0.000345             0.000345
# ...                                   ...                  ...
# True,yellow_card,7,3             0.000345             0.000345
# True,yellow_card,7,6             0.000345             0.000345
# True,yellow_card,7,9             0.000345             0.000345
# True,yellow_card,8,1             0.000345             0.000345
# True,yellow_card,9,4             0.000345             0.000345
#
#                       False,bad_touch,0,2  False,bad_touch,0,3  \
# row_0
# False,bad_touch,0,0              0.000346             0.000346
# False,bad_touch,0,1              0.000346             0.000346
# False,bad_touch,0,2              0.000346             0.000346
# False,bad_touch,0,3              0.000346             0.000346
# False,bad_touch,0,4              0.000346             0.000346
# ...                                   ...                  ...
# True,yellow_card,7,3             0.000346             0.000346
# True,yellow_card,7,6             0.000346             0.000346
# True,yellow_card,7,9             0.000346             0.000346
# True,yellow_card,8,1             0.000346             0.000346
# True,yellow_card,9,4             0.000346             0.000346
#
#                       False,bad_touch,0,4  False,bad_touch,0,5  \
# row_0
# False,bad_touch,0,0              0.000343             0.000344
# False,bad_touch,0,1              0.000343             0.000344
# False,bad_touch,0,2              0.000343             0.000344
# False,bad_touch,0,3              0.000343             0.000344
# False,bad_touch,0,4              0.000343             0.000344
# ...                                   ...                  ...
# True,yellow_card,7,3             0.000343             0.000344
# True,yellow_card,7,6             0.000343             0.000344
# True,yellow_card,7,9             0.000343             0.000344
# True,yellow_card,8,1             0.000343             0.000344
# True,yellow_card,9,4             0.000343             0.000344
#
#                       False,bad_touch,0,6  False,bad_touch,0,7  \
# row_0
# False,bad_touch,0,0              0.000347             0.000344
# False,bad_touch,0,1              0.000347             0.000344
# False,bad_touch,0,2              0.000347             0.000344
# False,bad_touch,0,3              0.000347             0.000344
# False,bad_touch,0,4              0.000347             0.000344
# ...                                   ...                  ...
# True,yellow_card,7,3             0.000347             0.000344
# True,yellow_card,7,6             0.000347             0.000344
# True,yellow_card,7,9             0.000347             0.000344
# True,yellow_card,8,1             0.000347             0.000344
# True,yellow_card,9,4             0.000347             0.000344
#
#                       False,bad_touch,0,8  False,bad_touch,0,9  ...  \
# row_0                                                           ...
# False,bad_touch,0,0              0.000342             0.000342  ...
# False,bad_touch,0,1              0.000342             0.000342  ...
# False,bad_touch,0,2              0.000342             0.000342  ...
# False,bad_touch,0,3              0.000342             0.000342  ...
# False,bad_touch,0,4              0.000342             0.000342  ...
# ...                                   ...                  ...  ...
# True,yellow_card,7,3             0.000342             0.000342  ...
# True,yellow_card,7,6             0.000342             0.000342  ...
# True,yellow_card,7,9             0.000342             0.000342  ...
# True,yellow_card,8,1             0.000342             0.000342  ...
# True,yellow_card,9,4             0.000342             0.000342  ...
#
#                       True,yellow_card,6,6  True,yellow_card,6,8  \
# row_0
# False,bad_touch,0,0                0.00035               0.00035
# False,bad_touch,0,1                0.00035               0.00035
# False,bad_touch,0,2                0.00035               0.00035
# False,bad_touch,0,3                0.00035               0.00035
# False,bad_touch,0,4                0.00035               0.00035
# ...                                    ...                   ...
# True,yellow_card,7,3               0.00035               0.00035
# True,yellow_card,7,6               0.00035               0.00035
# True,yellow_card,7,9               0.00035               0.00035
# True,yellow_card,8,1               0.00035               0.00035
# True,yellow_card,9,4               0.00035               0.00035
#
#                       True,yellow_card,6,9  True,yellow_card,7,0  \
# row_0
# False,bad_touch,0,0                0.00035               0.00035
# False,bad_touch,0,1                0.00035               0.00035
# False,bad_touch,0,2                0.00035               0.00035
# False,bad_touch,0,3                0.00035               0.00035
# False,bad_touch,0,4                0.00035               0.00035
# ...                                    ...                   ...
# True,yellow_card,7,3               0.00035               0.00035
# True,yellow_card,7,6               0.00035               0.00035
# True,yellow_card,7,9               0.00035               0.00035
# True,yellow_card,8,1               0.00035               0.00035
# True,yellow_card,9,4               0.00035               0.00035
#
#                       True,yellow_card,7,2  True,yellow_card,7,3  \
# row_0
# False,bad_touch,0,0                0.00035               0.00035
# False,bad_touch,0,1                0.00035               0.00035
# False,bad_touch,0,2                0.00035               0.00035
# False,bad_touch,0,3                0.00035               0.00035
# False,bad_touch,0,4                0.00035               0.00035
# ...                                    ...                   ...
# True,yellow_card,7,3               0.00035               0.00035
# True,yellow_card,7,6               0.00035               0.00035
# True,yellow_card,7,9               0.00035               0.00035
# True,yellow_card,8,1               0.00035               0.00035
# True,yellow_card,9,4               0.00035               0.00035
#
#                       True,yellow_card,7,6  True,yellow_card,7,9  \
# row_0
# False,bad_touch,0,0                0.00035               0.00035
# False,bad_touch,0,1                0.00035               0.00035
# False,bad_touch,0,2                0.00035               0.00035
# False,bad_touch,0,3                0.00035               0.00035
# False,bad_touch,0,4                0.00035               0.00035
# ...                                    ...                   ...
# True,yellow_card,7,3               0.00035               0.00035
# True,yellow_card,7,6               0.00035               0.00035
# True,yellow_card,7,9               0.00035               0.00035
# True,yellow_card,8,1               0.00035               0.00035
# True,yellow_card,9,4               0.00035               0.00035
#
#                       True,yellow_card,8,1  True,yellow_card,9,4
# row_0
# False,bad_touch,0,0                0.00035               0.00035
# False,bad_touch,0,1                0.00035               0.00035
# False,bad_touch,0,2                0.00035               0.00035
# False,bad_touch,0,3                0.00035               0.00035
# False,bad_touch,0,4                0.00035               0.00035
# ...                                    ...                   ...
# True,yellow_card,7,3               0.00035               0.00035
# True,yellow_card,7,6               0.00035               0.00035
# True,yellow_card,7,9               0.00035               0.00035
# True,yellow_card,8,1               0.00035               0.00035
# True,yellow_card,9,4               0.00035               0.00035
#
# [2858 rows x 2858 columns]

# %%
def pred(tok):
    return vocab[counts[tok].argmax()]

test_accuracy = (
    df
    .query("match_id.isin(@test_groups)")
    .assign(
        y_true = lambda d: d.action_token.shift(-1),
        y_pred = lambda d: d.action_token.apply(pred)
    )
    .dropna()
    .assign(correct = lambda d: d.y_pred == d.y_true)
    ['correct'].value_counts(normalize = True)
)
test_accuracy
# Out:
# correct
# False    0.575921
# True     0.424079
# Name: proportion, dtype: float64

# %%
def prob(tok1, tok2):
    return probs[tok1][tok2]

probs = (
    df
    .query("match_id.isin(@test_groups)")
    .assign(
        y_true = lambda d: d.action_token.shift(-1),
        y_pred = lambda d: d.action_token.apply(pred)
    )
    .dropna()
    .assign(prob = lambda d: d.apply(lambda x: prob(x.action_token, x.y_true), axis=1))
)

probs
# Out:
#       match_id            action_token                  y_true  \
# 0          212          False,pass,4,4      False,receival,6,5
# 1          212      False,receival,6,5          False,pass,6,5
# 2          212          False,pass,6,5  False,interception,2,7
# 3          212  False,interception,2,7          False,pass,2,7
# 4          212          False,pass,2,7  False,interception,4,8
# ...        ...                     ...                     ...
# 3129        82          False,pass,7,0      False,receival,8,0
# 3130        82      False,receival,8,0       False,dribble,8,0
# 3131        82       False,dribble,8,0        False,tackle,9,0
# 3132        82        False,tackle,9,0       False,dribble,9,0
# 3133        82       False,dribble,9,0          False,pass,8,1
#
#                   y_pred      prob
# 0     False,receival,5,5  0.010901
# 1      False,dribble,6,5  0.031392
# 2     False,receival,6,3  0.000661
# 3      False,dribble,2,7  0.054722
# 4     False,receival,3,9  0.001967
# ...                  ...       ...
# 3129  False,receival,6,0  0.026809
# 3130   False,dribble,8,0  0.276458
# 3131      False,pass,8,0  0.004378
# 3132   False,dribble,9,0  0.024542
# 3133      False,pass,9,0  0.004427
#
# [97720 rows x 5 columns]

# %%
np.log(probs['prob']).sum()
# Out:
# -383490.09516024316
