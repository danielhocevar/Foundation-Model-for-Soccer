# %%
import json
import torch
with open('action_types.json', 'r') as f:
    action_types = json.load(f)
action_types
# Out:
# {'0': 'pass',
#  '1': 'cross',
#  '2': 'throw_in',
#  '3': 'freekick_crossed',
#  '4': 'freekick_short',
#  '5': 'corner_crossed',
#  '6': 'corner_short',
#  '7': 'take_on',
#  '8': 'foul',
#  '9': 'tackle',
#  '10': 'interception',
#  '11': 'shot',
#  '12': 'shot_penalty',
#  '13': 'shot_freekick',
#  '14': 'keeper_save',
#  '15': 'keeper_claim',
#  '16': 'keeper_punch',
#  '17': 'keeper_pick_up',
#  '18': 'clearance',
#  '19': 'bad_touch',
#  '20': 'non_action',
#  '21': 'dribble',
#  '22': 'goalkick',
#  '23': 'receival',
#  '24': 'interception',
#  '25': 'out',
#  '26': 'offside',
#  '27': 'goal',
#  '28': 'owngoal',
#  '29': 'yellow_card',
#  '30': 'red_card',
#  '31': 'corner',
#  '32': 'freekick'}

# %%
import pandas as pd

df = pd.read_csv("WSL_actions.csv", index_col = 0)

grouped = df.groupby(['game_id', 'period_id'])
len(grouped)
# Out:
# 652

# %%
from preprocess_data import *

Xs = []
ys = []
for name, group in list(grouped):
    # print(f"Processing {len(group):>4} actions from game_id {name[0]: >5} half {name[1]}...")
    
    tokens = (
        group
        .pipe(add_coordinate_bins, n_bins_x = 10, n_bins_y = 10)
        .pipe(add_team_as_dummy)
        .pipe(get_action_type_names, action_types)
        .pipe(get_action_tokens)
        ['action_token'].values
    )

    X, y = sequence_to_sliding_window(tokens, n_prev_actions = 5)
    new_y = [np.concatenate((X[i][1:], np.array([y[i]]))) for i in range(len(X))]
    Xs.append(X)
    ys.append(y)
# Out:
# [array(['True,receival,4,4', 'True,dribble,4,4', 'True,pass,4,4',
#        'True,receival,3,0', 'True,dribble,3,0'], dtype=object), array(['True,dribble,4,4', 'True,pass,4,4', 'True,receival,3,0',
#        'True,dribble,3,0', 'True,bad_touch,1,1'], dtype=object), array(['True,pass,4,4', 'True,receival,3,0', 'True,dribble,3,0',
#        'True,bad_touch,1,1', 'False,goalkick,0,4'], dtype=object), array(['True,receival,3,0', 'True,dribble,3,0', 'True,bad_touch,1,1',
#        'False,goalkick,0,4', 'True,interception,4,1'], dtype=object), array(['True,dribble,3,0', 'True,bad_touch,1,1', 'False,goalkick,0,4',
#        'True,interception,4,1', 'True,pass,4,1'], dtype=object), array(['True,bad_touch,1,1', 'False,goalkick,0,4',
#        'True,interception,4,1', 'True,pass,4,1', 'False,interception,3,1'],
#       dtype=object), array(['False,goalkick,0,4', 'True,interception,4,1', 'True,pass,4,1',
#        'False,interception,3,1', 'False,pass,3,1'], dtype=object), array(['True,interception,4,1', 'True,pass,4,1', 'False,interception,3,1',
#        'False,pass,3,1', 'False,receival,3,0'], dtype=object), array(['True,pass,4,1', 'False,interception,3,1', 'False,pass,3,1',
#        'False,receival,3,0', 'False,pass,3,1'], dtype=object), array(['False,interception,3,1', 'False,pass,3,1', 'False,receival,3,0',
#        'False,pass,3,1', 'False,receival,4,0'], dtype=object), array(['False,pass,3,1', 'False,receival,3,0', 'False,pass,3,1',
#        'False,receival,4,0', 'False,dribble,4,0'], dtype=object), array(['False,receival,3,0', 'False,pass,3,1', 'False,receival,4,0',
#        'False,dribble,4,0', 'False,pass,4,0'], dtype=object), array(['False,pass,3,1', 'False,receival,4,0', 'False,dribble,4,0',
#        'False,pass,4,0', 'False,receival,6,1'], dtype=object), array(['False,receival,4,0', 'False,dribble,4,0', 'False,pass,4,0',
#        'False,receival,6,1', 'False,dribble,6,1'], dtype=object), array(['False,dribble,4,0', 'False,pass,4,0', 'False,receival,6,1',
#        'False,dribble,6,1', 'False,bad_touch,6,1'], dtype=object), array(['False,pass,4,0', 'False,receival,6,1', 'False,dribble,6,1',
#        'False,bad_touch,6,1', 'True,dribble,6,1'], dtype=object), array(['False,receival,6,1', 'False,dribble,6,1', 'False,bad_touch,6,1',
#        'True,dribble,6,1', 'True,pass,6,2'], dtype=object), array(['False,dribble,6,1', 'False,bad_touch,6,1', 'True,dribble,6,1',
#        'True,pass,6,2', 'True,receival,2,2'], dtype=object), array(['False,bad_touch,6,1', 'True,dribble,6,1', 'True,pass,6,2',
#        'True,receival,2,2', 'True,dribble,2,2'], dtype=object), array(['True,dribble,6,1', 'True,pass,6,2', 'True,receival,2,2',
#        'True,dribble,2,2', 'True,take_on,1,2'], dtype=object), array(['True,pass,6,2', 'True,receival,2,2', 'True,dribble,2,2',
#        'True,take_on,1,2', 'True,dribble,1,2'], dtype=object), array(['True,receival,2,2', 'True,dribble,2,2', 'True,take_on,1,2',
#        'True,dribble,1,2', 'True,take_on,0,2'], dtype=object), array(['True,dribble,2,2', 'True,take_on,1,2', 'True,dribble,1,2',
#        'True,take_on,0,2', 'True,dribble,0,2'], dtype=object), array(['True,take_on,1,2', 'True,dribble,1,2', 'True,take_on,0,2',
#        'True,dribble,0,2', 'True,shot,0,3'], dtype=object), array(['True,dribble,1,2', 'True,take_on,0,2', 'True,dribble,0,2',
#        'True,shot,0,3', 'True,out,0,4'], dtype=object), array(['True,take_on,0,2', 'True,dribble,0,2', 'True,shot,0,3',
#        'True,out,0,4', 'True,corner,0,0'], dtype=object), array(['True,dribble,0,2', 'True,shot,0,3', 'True,out,0,4',
#        'True,corner,0,0', 'False,interception,0,4'], dtype=object), array(['True,shot,0,3', 'True,out,0,4', 'True,corner,0,0',
#        'False,interception,0,4', 'False,clearance,0,4'], dtype=object), array(['True,out,0,4', 'True,corner,0,0', 'False,interception,0,4',
#        'False,clearance,0,4', 'True,interception,5,3'], dtype=object), array(['True,corner,0,0', 'False,interception,0,4', 'False,clearance,0,4',
#        'True,interception,5,3', 'True,dribble,5,3'], dtype=object), array(['False,interception,0,4', 'False,clearance,0,4',
#        'True,interception,5,3', 'True,dribble,5,3', 'True,pass,5,2'],
#       dtype=object), array(['False,clearance,0,4', 'True,interception,5,3', 'True,dribble,5,3',
#        'True,pass,5,2', 'False,interception,5,3'], dtype=object), array(['True,interception,5,3', 'True,dribble,5,3', 'True,pass,5,2',
#        'False,interception,5,3', 'False,dribble,5,3'], dtype=object), array(['True,dribble,5,3', 'True,pass,5,2', 'False,interception,5,3',
#        'False,dribble,5,3', 'False,dribble,5,3'], dtype=object), array(['True,pass,5,2', 'False,interception,5,3', 'False,dribble,5,3',
#        'False,dribble,5,3', 'False,pass,7,6'], dtype=object), array(['False,interception,5,3', 'False,dribble,5,3', 'False,dribble,5,3',
#        'False,pass,7,6', 'False,receival,7,9'], dtype=object), array(['False,dribble,5,3', 'False,dribble,5,3', 'False,pass,7,6',
#        'False,receival,7,9', 'False,dribble,7,9'], dtype=object), array(['False,dribble,5,3', 'False,pass,7,6', 'False,receival,7,9',
#        'False,dribble,7,9', 'False,pass,7,9'], dtype=object), array(['False,pass,7,6', 'False,receival,7,9', 'False,dribble,7,9',
#        'False,pass,7,9', 'False,receival,7,8'], dtype=object), array(['False,receival,7,9', 'False,dribble,7,9', 'False,pass,7,9',
#        'False,receival,7,8', 'False,dribble,7,8'], dtype=object), array(['False,dribble,7,9', 'False,pass,7,9', 'False,receival,7,8',
#        'False,dribble,7,8', 'False,cross,7,7'], dtype=object), array(['False,pass,7,9', 'False,receival,7,8', 'False,dribble,7,8',
#        'False,cross,7,7', 'False,receival,8,5'], dtype=object), array(['False,receival,7,8', 'False,dribble,7,8', 'False,cross,7,7',
#        'False,receival,8,5', 'False,dribble,8,5'], dtype=object), array(['False,dribble,7,8', 'False,cross,7,7', 'False,receival,8,5',
#        'False,dribble,8,5', 'False,pass,8,5'], dtype=object), array(['False,cross,7,7', 'False,receival,8,5', 'False,dribble,8,5',
#        'False,pass,8,5', 'False,receival,7,3'], dtype=object), array(['False,receival,8,5', 'False,dribble,8,5', 'False,pass,8,5',
#        'False,receival,7,3', 'False,dribble,7,3'], dtype=object), array(['False,dribble,8,5', 'False,pass,8,5', 'False,receival,7,3',
#        'False,dribble,7,3', 'False,pass,7,3'], dtype=object), array(['False,pass,8,5', 'False,receival,7,3', 'False,dribble,7,3',
#        'False,pass,7,3', 'False,receival,8,2'], dtype=object), array(['False,receival,7,3', 'False,dribble,7,3', 'False,pass,7,3',
#        'False,receival,8,2', 'False,dribble,8,2'], dtype=object), array(['False,dribble,7,3', 'False,pass,7,3', 'False,receival,8,2',
#        'False,dribble,8,2', 'False,take_on,9,2'], dtype=object), array(['False,pass,7,3', 'False,receival,8,2', 'False,dribble,8,2',
#        'False,take_on,9,2', 'True,tackle,9,2'], dtype=object), array(['False,receival,8,2', 'False,dribble,8,2', 'False,take_on,9,2',
#        'True,tackle,9,2', 'False,corner,9,0'], dtype=object), array(['False,dribble,8,2', 'False,take_on,9,2', 'True,tackle,9,2',
#        'False,corner,9,0', 'True,keeper_punch,9,4'], dtype=object), array(['False,take_on,9,2', 'True,tackle,9,2', 'False,corner,9,0',
#        'True,keeper_punch,9,4', 'True,dribble,9,4'], dtype=object), array(['True,tackle,9,2', 'False,corner,9,0', 'True,keeper_punch,9,4',
#        'True,dribble,9,4', 'True,dribble,9,4'], dtype=object), array(['False,corner,9,0', 'True,keeper_punch,9,4', 'True,dribble,9,4',
#        'True,dribble,9,4', 'True,pass,9,5'], dtype=object), array(['True,keeper_punch,9,4', 'True,dribble,9,4', 'True,dribble,9,4',
#        'True,pass,9,5', 'True,receival,6,5'], dtype=object), array(['True,dribble,9,4', 'True,dribble,9,4', 'True,pass,9,5',
#        'True,receival,6,5', 'True,dribble,6,5'], dtype=object), array(['True,dribble,9,4', 'True,pass,9,5', 'True,receival,6,5',
#        'True,dribble,6,5', 'True,pass,7,4'], dtype=object), array(['True,pass,9,5', 'True,receival,6,5', 'True,dribble,6,5',
#        'True,pass,7,4', 'True,receival,7,6'], dtype=object), array(['True,receival,6,5', 'True,dribble,6,5', 'True,pass,7,4',
#        'True,receival,7,6', 'True,dribble,7,6'], dtype=object), array(['True,dribble,6,5', 'True,pass,7,4', 'True,receival,7,6',
#        'True,dribble,7,6', 'True,pass,7,7'], dtype=object), array(['True,pass,7,4', 'True,receival,7,6', 'True,dribble,7,6',
#        'True,pass,7,7', 'False,interception,2,8'], dtype=object), array(['True,receival,7,6', 'True,dribble,7,6', 'True,pass,7,7',
#        'False,interception,2,8', 'False,pass,2,8'], dtype=object), array(['True,dribble,7,6', 'True,pass,7,7', 'False,interception,2,8',
#        'False,pass,2,8', 'False,receival,3,8'], dtype=object), array(['True,pass,7,7', 'False,interception,2,8', 'False,pass,2,8',
#        'False,receival,3,8', 'False,dribble,3,8'], dtype=object), array(['False,interception,2,8', 'False,pass,2,8', 'False,receival,3,8',
#        'False,dribble,3,8', 'False,take_on,3,9'], dtype=object), array(['False,pass,2,8', 'False,receival,3,8', 'False,dribble,3,8',
#        'False,take_on,3,9', 'True,tackle,3,9'], dtype=object), array(['False,receival,3,8', 'False,dribble,3,8', 'False,take_on,3,9',
#        'True,tackle,3,9', 'False,dribble,3,9'], dtype=object), array(['False,dribble,3,8', 'False,take_on,3,9', 'True,tackle,3,9',
#        'False,dribble,3,9', 'True,tackle,4,9'], dtype=object), array(['False,take_on,3,9', 'True,tackle,3,9', 'False,dribble,3,9',
#        'True,tackle,4,9', 'True,dribble,4,9'], dtype=object), array(['True,tackle,3,9', 'False,dribble,3,9', 'True,tackle,4,9',
#        'True,dribble,4,9', 'True,pass,3,9'], dtype=object), array(['False,dribble,3,9', 'True,tackle,4,9', 'True,dribble,4,9',
#        'True,pass,3,9', 'True,receival,3,9'], dtype=object), array(['True,tackle,4,9', 'True,dribble,4,9', 'True,pass,3,9',
#        'True,receival,3,9', 'True,pass,3,9'], dtype=object), array(['True,dribble,4,9', 'True,pass,3,9', 'True,receival,3,9',
#        'True,pass,3,9', 'True,receival,3,8'], dtype=object), array(['True,pass,3,9', 'True,receival,3,9', 'True,pass,3,9',
#        'True,receival,3,8', 'True,dribble,3,8'], dtype=object), array(['True,receival,3,9', 'True,pass,3,9', 'True,receival,3,8',
#        'True,dribble,3,8', 'True,pass,3,8'], dtype=object), array(['True,pass,3,9', 'True,receival,3,8', 'True,dribble,3,8',
#        'True,pass,3,8', 'True,receival,2,8'], dtype=object), array(['True,receival,3,8', 'True,dribble,3,8', 'True,pass,3,8',
#        'True,receival,2,8', 'True,dribble,2,8'], dtype=object), array(['True,dribble,3,8', 'True,pass,3,8', 'True,receival,2,8',
#        'True,dribble,2,8', 'True,pass,2,8'], dtype=object), array(['True,pass,3,8', 'True,receival,2,8', 'True,dribble,2,8',
#        'True,pass,2,8', 'False,interception,2,6'], dtype=object), array(['True,receival,2,8', 'True,dribble,2,8', 'True,pass,2,8',
#        'False,interception,2,6', 'False,pass,2,6'], dtype=object), array(['True,dribble,2,8', 'True,pass,2,8', 'False,interception,2,6',
#        'False,pass,2,6', 'False,receival,2,7'], dtype=object), array(['True,pass,2,8', 'False,interception,2,6', 'False,pass,2,6',
#        'False,receival,2,7', 'False,dribble,2,7'], dtype=object), array(['False,interception,2,6', 'False,pass,2,6', 'False,receival,2,7',
#        'False,dribble,2,7', 'False,pass,2,7'], dtype=object), array(['False,pass,2,6', 'False,receival,2,7', 'False,dribble,2,7',
#        'False,pass,2,7', 'False,receival,2,6'], dtype=object), array(['False,receival,2,7', 'False,dribble,2,7', 'False,pass,2,7',
#        'False,receival,2,6', 'False,dribble,2,6'], dtype=object), array(['False,dribble,2,7', 'False,pass,2,7', 'False,receival,2,6',
#        'False,dribble,2,6', 'False,pass,2,6'], dtype=object), array(['False,pass,2,7', 'False,receival,2,6', 'False,dribble,2,6',
#        'False,pass,2,6', 'False,receival,2,8'], dtype=object), array(['False,receival,2,6', 'False,dribble,2,6', 'False,pass,2,6',
#        'False,receival,2,8', 'False,dribble,2,8'], dtype=object), array(['False,dribble,2,6', 'False,pass,2,6', 'False,receival,2,8',
#        'False,dribble,2,8', 'False,pass,2,8'], dtype=object), array(['False,pass,2,6', 'False,receival,2,8', 'False,dribble,2,8',
#        'False,pass,2,8', 'True,interception,8,7'], dtype=object), array(['False,receival,2,8', 'False,dribble,2,8', 'False,pass,2,8',
#        'True,interception,8,7', 'True,dribble,8,7'], dtype=object), array(['False,dribble,2,8', 'False,pass,2,8', 'True,interception,8,7',
#        'True,dribble,8,7', 'True,pass,8,6'], dtype=object), array(['False,pass,2,8', 'True,interception,8,7', 'True,dribble,8,7',
#        'True,pass,8,6', 'True,receival,7,3'], dtype=object), array(['True,interception,8,7', 'True,dribble,8,7', 'True,pass,8,6',
#        'True,receival,7,3', 'True,dribble,7,3'], dtype=object), array(['True,dribble,8,7', 'True,pass,8,6', 'True,receival,7,3',
#        'True,dribble,7,3', 'True,pass,6,3'], dtype=object), array(['True,pass,8,6', 'True,receival,7,3', 'True,dribble,7,3',
#        'True,pass,6,3', 'True,receival,4,2'], dtype=object), array(['True,receival,7,3', 'True,dribble,7,3', 'True,pass,6,3',
#        'True,receival,4,2', 'True,dribble,4,2'], dtype=object), array(['True,dribble,7,3', 'True,pass,6,3', 'True,receival,4,2',
#        'True,dribble,4,2', 'False,tackle,4,2'], dtype=object), array(['True,pass,6,3', 'True,receival,4,2', 'True,dribble,4,2',
#        'False,tackle,4,2', 'False,dribble,4,2'], dtype=object), array(['True,receival,4,2', 'True,dribble,4,2', 'False,tackle,4,2',
#        'False,dribble,4,2', 'False,dribble,4,2'], dtype=object), array(['True,dribble,4,2', 'False,tackle,4,2', 'False,dribble,4,2',
#        'False,dribble,4,2', 'False,pass,5,0'], dtype=object), array(['False,tackle,4,2', 'False,dribble,4,2', 'False,dribble,4,2',
#        'False,pass,5,0', 'False,receival,3,0'], dtype=object), array(['False,dribble,4,2', 'False,dribble,4,2', 'False,pass,5,0',
#        'False,receival,3,0', 'False,dribble,3,0'], dtype=object), array(['False,dribble,4,2', 'False,pass,5,0', 'False,receival,3,0',
#        'False,dribble,3,0', 'False,pass,3,0'], dtype=object), array(['False,pass,5,0', 'False,receival,3,0', 'False,dribble,3,0',
#        'False,pass,3,0', 'False,receival,2,2'], dtype=object), array(['False,receival,3,0', 'False,dribble,3,0', 'False,pass,3,0',
#        'False,receival,2,2', 'False,dribble,2,2'], dtype=object), array(['False,dribble,3,0', 'False,pass,3,0', 'False,receival,2,2',
#        'False,dribble,2,2', 'False,pass,3,3'], dtype=object), array(['False,pass,3,0', 'False,receival,2,2', 'False,dribble,2,2',
#        'False,pass,3,3', 'False,receival,2,6'], dtype=object), array(['False,receival,2,2', 'False,dribble,2,2', 'False,pass,3,3',
#        'False,receival,2,6', 'False,dribble,2,6'], dtype=object), array(['False,dribble,2,2', 'False,pass,3,3', 'False,receival,2,6',
#        'False,dribble,2,6', 'False,pass,2,6'], dtype=object), array(['False,pass,3,3', 'False,receival,2,6', 'False,dribble,2,6',
#        'False,pass,2,6', 'False,receival,3,9'], dtype=object), array(['False,receival,2,6', 'False,dribble,2,6', 'False,pass,2,6',
#        'False,receival,3,9', 'False,dribble,3,9'], dtype=object), array(['False,dribble,2,6', 'False,pass,2,6', 'False,receival,3,9',
#        'False,dribble,3,9', 'False,pass,3,9'], dtype=object), array(['False,pass,2,6', 'False,receival,3,9', 'False,dribble,3,9',
#        'False,pass,3,9', 'False,receival,5,8'], dtype=object), array(['False,receival,3,9', 'False,dribble,3,9', 'False,pass,3,9',
#        'False,receival,5,8', 'False,dribble,5,8'], dtype=object), array(['False,dribble,3,9', 'False,pass,3,9', 'False,receival,5,8',
#        'False,dribble,5,8', 'True,tackle,4,9'], dtype=object), array(['False,pass,3,9', 'False,receival,5,8', 'False,dribble,5,8',
#        'True,tackle,4,9', 'True,dribble,4,9'], dtype=object), array(['False,receival,5,8', 'False,dribble,5,8', 'True,tackle,4,9',
#        'True,dribble,4,9', 'True,pass,3,8'], dtype=object), array(['False,dribble,5,8', 'True,tackle,4,9', 'True,dribble,4,9',
#        'True,pass,3,8', 'True,receival,2,7'], dtype=object), array(['True,tackle,4,9', 'True,dribble,4,9', 'True,pass,3,8',
#        'True,receival,2,7', 'True,dribble,2,7'], dtype=object), array(['True,dribble,4,9', 'True,pass,3,8', 'True,receival,2,7',
#        'True,dribble,2,7', 'False,tackle,2,7'], dtype=object), array(['True,pass,3,8', 'True,receival,2,7', 'True,dribble,2,7',
#        'False,tackle,2,7', 'False,dribble,2,7'], dtype=object), array(['True,receival,2,7', 'True,dribble,2,7', 'False,tackle,2,7',
#        'False,dribble,2,7', 'False,dribble,2,6'], dtype=object), array(['True,dribble,2,7', 'False,tackle,2,7', 'False,dribble,2,7',
#        'False,dribble,2,6', 'False,pass,3,5'], dtype=object), array(['False,tackle,2,7', 'False,dribble,2,7', 'False,dribble,2,6',
#        'False,pass,3,5', 'False,receival,4,6'], dtype=object), array(['False,dribble,2,7', 'False,dribble,2,6', 'False,pass,3,5',
#        'False,receival,4,6', 'False,dribble,4,6'], dtype=object), array(['False,dribble,2,6', 'False,pass,3,5', 'False,receival,4,6',
#        'False,dribble,4,6', 'False,bad_touch,4,6'], dtype=object), array(['False,pass,3,5', 'False,receival,4,6', 'False,dribble,4,6',
#        'False,bad_touch,4,6', 'False,dribble,4,6'], dtype=object), array(['False,receival,4,6', 'False,dribble,4,6', 'False,bad_touch,4,6',
#        'False,dribble,4,6', 'False,pass,4,7'], dtype=object), array(['False,dribble,4,6', 'False,bad_touch,4,6', 'False,dribble,4,6',
#        'False,pass,4,7', 'False,receival,3,9'], dtype=object), array(['False,bad_touch,4,6', 'False,dribble,4,6', 'False,pass,4,7',
#        'False,receival,3,9', 'False,dribble,3,9'], dtype=object), array(['False,dribble,4,6', 'False,pass,4,7', 'False,receival,3,9',
#        'False,dribble,3,9', 'False,pass,3,9'], dtype=object), array(['False,pass,4,7', 'False,receival,3,9', 'False,dribble,3,9',
#        'False,pass,3,9', 'False,receival,3,8'], dtype=object), array(['False,receival,3,9', 'False,dribble,3,9', 'False,pass,3,9',
#        'False,receival,3,8', 'False,dribble,3,8'], dtype=object), array(['False,dribble,3,9', 'False,pass,3,9', 'False,receival,3,8',
#        'False,dribble,3,8', 'False,pass,2,8'], dtype=object), array(['False,pass,3,9', 'False,receival,3,8', 'False,dribble,3,8',
#        'False,pass,2,8', 'False,receival,2,6'], dtype=object), array(['False,receival,3,8', 'False,dribble,3,8', 'False,pass,2,8',
#        'False,receival,2,6', 'False,dribble,2,6'], dtype=object), array(['False,dribble,3,8', 'False,pass,2,8', 'False,receival,2,6',
#        'False,dribble,2,6', 'False,pass,1,6'], dtype=object), array(['False,pass,2,8', 'False,receival,2,6', 'False,dribble,2,6',
#        'False,pass,1,6', 'True,interception,3,0'], dtype=object), array(['False,receival,2,6', 'False,dribble,2,6', 'False,pass,1,6',
#        'True,interception,3,0', 'True,dribble,3,0'], dtype=object), array(['False,dribble,2,6', 'False,pass,1,6', 'True,interception,3,0',
#        'True,dribble,3,0', 'True,bad_touch,3,0'], dtype=object), array(['False,pass,1,6', 'True,interception,3,0', 'True,dribble,3,0',
#        'True,bad_touch,3,0', 'False,throw_in,4,0'], dtype=object), array(['True,interception,3,0', 'True,dribble,3,0', 'True,bad_touch,3,0',
#        'False,throw_in,4,0', 'False,receival,3,0'], dtype=object), array(['True,dribble,3,0', 'True,bad_touch,3,0', 'False,throw_in,4,0',
#        'False,receival,3,0', 'False,dribble,3,0'], dtype=object), array(['True,bad_touch,3,0', 'False,throw_in,4,0', 'False,receival,3,0',
#        'False,dribble,3,0', 'False,pass,3,0'], dtype=object), array(['False,throw_in,4,0', 'False,receival,3,0', 'False,dribble,3,0',
#        'False,pass,3,0', 'False,receival,5,1'], dtype=object), array(['False,receival,3,0', 'False,dribble,3,0', 'False,pass,3,0',
#        'False,receival,5,1', 'False,dribble,5,1'], dtype=object), array(['False,dribble,3,0', 'False,pass,3,0', 'False,receival,5,1',
#        'False,dribble,5,1', 'False,pass,5,1'], dtype=object), array(['False,pass,3,0', 'False,receival,5,1', 'False,dribble,5,1',
#        'False,pass,5,1', 'False,receival,5,0'], dtype=object), array(['False,receival,5,1', 'False,dribble,5,1', 'False,pass,5,1',
#        'False,receival,5,0', 'False,dribble,5,0'], dtype=object), array(['False,dribble,5,1', 'False,pass,5,1', 'False,receival,5,0',
#        'False,dribble,5,0', 'False,bad_touch,5,0'], dtype=object), array(['False,pass,5,1', 'False,receival,5,0', 'False,dribble,5,0',
#        'False,bad_touch,5,0', 'True,throw_in,4,0'], dtype=object), array(['False,receival,5,0', 'False,dribble,5,0', 'False,bad_touch,5,0',
#        'True,throw_in,4,0', 'True,receival,2,0'], dtype=object), array(['False,dribble,5,0', 'False,bad_touch,5,0', 'True,throw_in,4,0',
#        'True,receival,2,0', 'True,dribble,2,0'], dtype=object), array(['False,bad_touch,5,0', 'True,throw_in,4,0', 'True,receival,2,0',
#        'True,dribble,2,0', 'True,pass,2,0'], dtype=object), array(['True,throw_in,4,0', 'True,receival,2,0', 'True,dribble,2,0',
#        'True,pass,2,0', 'True,receival,3,0'], dtype=object), array(['True,receival,2,0', 'True,dribble,2,0', 'True,pass,2,0',
#        'True,receival,3,0', 'True,dribble,3,0'], dtype=object), array(['True,dribble,2,0', 'True,pass,2,0', 'True,receival,3,0',
#        'True,dribble,3,0', 'True,pass,3,0'], dtype=object), array(['True,pass,2,0', 'True,receival,3,0', 'True,dribble,3,0',
#        'True,pass,3,0', 'True,receival,2,8'], dtype=object), array(['True,receival,3,0', 'True,dribble,3,0', 'True,pass,3,0',
#        'True,receival,2,8', 'True,dribble,2,8'], dtype=object), array(['True,dribble,3,0', 'True,pass,3,0', 'True,receival,2,8',
#        'True,dribble,2,8', 'True,pass,0,7'], dtype=object), array(['True,pass,3,0', 'True,receival,2,8', 'True,dribble,2,8',
#        'True,pass,0,7', 'True,receival,0,6'], dtype=object), array(['True,receival,2,8', 'True,dribble,2,8', 'True,pass,0,7',
#        'True,receival,0,6', 'True,dribble,0,6'], dtype=object), array(['True,dribble,2,8', 'True,pass,0,7', 'True,receival,0,6',
#        'True,dribble,0,6', 'True,dribble,0,8'], dtype=object), array(['True,pass,0,7', 'True,receival,0,6', 'True,dribble,0,6',
#        'True,dribble,0,8', 'True,pass,0,8'], dtype=object), array(['True,receival,0,6', 'True,dribble,0,6', 'True,dribble,0,8',
#        'True,pass,0,8', 'True,receival,2,8'], dtype=object), array(['True,dribble,0,6', 'True,dribble,0,8', 'True,pass,0,8',
#        'True,receival,2,8', 'True,dribble,2,8'], dtype=object), array(['True,dribble,0,8', 'True,pass,0,8', 'True,receival,2,8',
#        'True,dribble,2,8', 'True,cross,2,8'], dtype=object), array(['True,pass,0,8', 'True,receival,2,8', 'True,dribble,2,8',
#        'True,cross,2,8', 'True,receival,1,5'], dtype=object), array(['True,receival,2,8', 'True,dribble,2,8', 'True,cross,2,8',
#        'True,receival,1,5', 'True,pass,1,5'], dtype=object), array(['True,dribble,2,8', 'True,cross,2,8', 'True,receival,1,5',
#        'True,pass,1,5', 'True,receival,0,6'], dtype=object), array(['True,cross,2,8', 'True,receival,1,5', 'True,pass,1,5',
#        'True,receival,0,6', 'True,take_on,0,6'], dtype=object), array(['True,receival,1,5', 'True,pass,1,5', 'True,receival,0,6',
#        'True,take_on,0,6', 'True,dribble,0,6'], dtype=object), array(['True,pass,1,5', 'True,receival,0,6', 'True,take_on,0,6',
#        'True,dribble,0,6', 'True,shot,0,6'], dtype=object), array(['True,receival,0,6', 'True,take_on,0,6', 'True,dribble,0,6',
#        'True,shot,0,6', 'True,out,0,5'], dtype=object), array(['True,take_on,0,6', 'True,dribble,0,6', 'True,shot,0,6',
#        'True,out,0,5', 'True,corner,0,9'], dtype=object), array(['True,dribble,0,6', 'True,shot,0,6', 'True,out,0,5',
#        'True,corner,0,9', 'False,interception,1,6'], dtype=object), array(['True,shot,0,6', 'True,out,0,5', 'True,corner,0,9',
#        'False,interception,1,6', 'False,clearance,1,6'], dtype=object), array(['True,out,0,5', 'True,corner,0,9', 'False,interception,1,6',
#        'False,clearance,1,6', 'True,interception,1,6'], dtype=object), array(['True,corner,0,9', 'False,interception,1,6', 'False,clearance,1,6',
#        'True,interception,1,6', 'True,shot,1,6'], dtype=object), array(['False,interception,1,6', 'False,clearance,1,6',
#        'True,interception,1,6', 'True,shot,1,6', 'True,dribble,1,6'],
#       dtype=object), array(['False,clearance,1,6', 'True,interception,1,6', 'True,shot,1,6',
#        'True,dribble,1,6', 'True,dribble,0,4'], dtype=object), array(['True,interception,1,6', 'True,shot,1,6', 'True,dribble,1,6',
#        'True,dribble,0,4', 'True,shot,1,4'], dtype=object), array(['True,shot,1,6', 'True,dribble,1,6', 'True,dribble,0,4',
#        'True,shot,1,4', 'True,dribble,0,4'], dtype=object), array(['True,dribble,1,6', 'True,dribble,0,4', 'True,shot,1,4',
#        'True,dribble,0,4', 'True,pass,1,4'], dtype=object), array(['True,dribble,0,4', 'True,shot,1,4', 'True,dribble,0,4',
#        'True,pass,1,4', 'True,receival,0,3'], dtype=object), array(['True,shot,1,4', 'True,dribble,0,4', 'True,pass,1,4',
#        'True,receival,0,3', 'True,shot,1,3'], dtype=object), array(['True,dribble,0,4', 'True,pass,1,4', 'True,receival,0,3',
#        'True,shot,1,3', 'True,goal,0,5'], dtype=object), array(['True,pass,1,4', 'True,receival,0,3', 'True,shot,1,3',
#        'True,goal,0,5', 'False,pass,3,0'], dtype=object), array(['True,receival,0,3', 'True,shot,1,3', 'True,goal,0,5',
#        'False,pass,3,0', 'False,out,9,1'], dtype=object), array(['True,shot,1,3', 'True,goal,0,5', 'False,pass,3,0',
#        'False,out,9,1', 'True,goalkick,9,4'], dtype=object), array(['True,goal,0,5', 'False,pass,3,0', 'False,out,9,1',
#        'True,goalkick,9,4', 'True,receival,9,8'], dtype=object), array(['False,pass,3,0', 'False,out,9,1', 'True,goalkick,9,4',
#        'True,receival,9,8', 'True,dribble,9,8'], dtype=object), array(['False,out,9,1', 'True,goalkick,9,4', 'True,receival,9,8',
#        'True,dribble,9,8', 'True,pass,6,8'], dtype=object), array(['True,goalkick,9,4', 'True,receival,9,8', 'True,dribble,9,8',
#        'True,pass,6,8', 'False,interception,0,5'], dtype=object), array(['True,receival,9,8', 'True,dribble,9,8', 'True,pass,6,8',
#        'False,interception,0,5', 'False,dribble,0,5'], dtype=object), array(['True,dribble,9,8', 'True,pass,6,8', 'False,interception,0,5',
#        'False,dribble,0,5', 'False,pass,0,5'], dtype=object), array(['True,pass,6,8', 'False,interception,0,5', 'False,dribble,0,5',
#        'False,pass,0,5', 'False,receival,2,2'], dtype=object), array(['False,interception,0,5', 'False,dribble,0,5', 'False,pass,0,5',
#        'False,receival,2,2', 'False,dribble,2,2'], dtype=object), array(['False,dribble,0,5', 'False,pass,0,5', 'False,receival,2,2',
#        'False,dribble,2,2', 'False,pass,2,2'], dtype=object), array(['False,pass,0,5', 'False,receival,2,2', 'False,dribble,2,2',
#        'False,pass,2,2', 'False,receival,3,3'], dtype=object), array(['False,receival,2,2', 'False,dribble,2,2', 'False,pass,2,2',
#        'False,receival,3,3', 'False,dribble,3,3'], dtype=object), array(['False,dribble,2,2', 'False,pass,2,2', 'False,receival,3,3',
#        'False,dribble,3,3', 'False,pass,3,3'], dtype=object), array(['False,pass,2,2', 'False,receival,3,3', 'False,dribble,3,3',
#        'False,pass,3,3', 'False,receival,3,0'], dtype=object), array(['False,receival,3,3', 'False,dribble,3,3', 'False,pass,3,3',
#        'False,receival,3,0', 'False,dribble,3,0'], dtype=object), array(['False,dribble,3,3', 'False,pass,3,3', 'False,receival,3,0',
#        'False,dribble,3,0', 'False,pass,3,0'], dtype=object), array(['False,pass,3,3', 'False,receival,3,0', 'False,dribble,3,0',
#        'False,pass,3,0', 'False,receival,2,0'], dtype=object), array(['False,receival,3,0', 'False,dribble,3,0', 'False,pass,3,0',
#        'False,receival,2,0', 'False,dribble,2,0'], dtype=object), array(['False,dribble,3,0', 'False,pass,3,0', 'False,receival,2,0',
#        'False,dribble,2,0', 'False,pass,3,0'], dtype=object), array(['False,pass,3,0', 'False,receival,2,0', 'False,dribble,2,0',
#        'False,pass,3,0', 'False,receival,5,0'], dtype=object), array(['False,receival,2,0', 'False,dribble,2,0', 'False,pass,3,0',
#        'False,receival,5,0', 'False,dribble,5,0'], dtype=object), array(['False,dribble,2,0', 'False,pass,3,0', 'False,receival,5,0',
#        'False,dribble,5,0', 'False,bad_touch,6,0'], dtype=object), array(['False,pass,3,0', 'False,receival,5,0', 'False,dribble,5,0',
#        'False,bad_touch,6,0', 'True,pass,5,0'], dtype=object), array(['False,receival,5,0', 'False,dribble,5,0', 'False,bad_touch,6,0',
#        'True,pass,5,0', 'True,receival,6,0'], dtype=object), array(['False,dribble,5,0', 'False,bad_touch,6,0', 'True,pass,5,0',
#        'True,receival,6,0', 'True,dribble,6,0'], dtype=object), array(['False,bad_touch,6,0', 'True,pass,5,0', 'True,receival,6,0',
#        'True,dribble,6,0', 'True,pass,6,0'], dtype=object), array(['True,pass,5,0', 'True,receival,6,0', 'True,dribble,6,0',
#        'True,pass,6,0', 'False,interception,5,2'], dtype=object), array(['True,receival,6,0', 'True,dribble,6,0', 'True,pass,6,0',
#        'False,interception,5,2', 'False,pass,5,2'], dtype=object), array(['True,dribble,6,0', 'True,pass,6,0', 'False,interception,5,2',
#        'False,pass,5,2', 'False,receival,6,2'], dtype=object), array(['True,pass,6,0', 'False,interception,5,2', 'False,pass,5,2',
#        'False,receival,6,2', 'False,dribble,6,2'], dtype=object), array(['False,interception,5,2', 'False,pass,5,2', 'False,receival,6,2',
#        'False,dribble,6,2', 'False,pass,6,2'], dtype=object), array(['False,pass,5,2', 'False,receival,6,2', 'False,dribble,6,2',
#        'False,pass,6,2', 'False,receival,5,4'], dtype=object), array(['False,receival,6,2', 'False,dribble,6,2', 'False,pass,6,2',
#        'False,receival,5,4', 'False,dribble,5,4'], dtype=object), array(['False,dribble,6,2', 'False,pass,6,2', 'False,receival,5,4',
#        'False,dribble,5,4', 'False,pass,6,4'], dtype=object), array(['False,pass,6,2', 'False,receival,5,4', 'False,dribble,5,4',
#        'False,pass,6,4', 'False,receival,6,9'], dtype=object), array(['False,receival,5,4', 'False,dribble,5,4', 'False,pass,6,4',
#        'False,receival,6,9', 'False,dribble,6,9'], dtype=object), array(['False,dribble,5,4', 'False,pass,6,4', 'False,receival,6,9',
#        'False,dribble,6,9', 'False,pass,7,8'], dtype=object), array(['False,pass,6,4', 'False,receival,6,9', 'False,dribble,6,9',
#        'False,pass,7,8', 'False,receival,8,9'], dtype=object), array(['False,receival,6,9', 'False,dribble,6,9', 'False,pass,7,8',
#        'False,receival,8,9', 'False,dribble,8,9'], dtype=object), array(['False,dribble,6,9', 'False,pass,7,8', 'False,receival,8,9',
#        'False,dribble,8,9', 'False,pass,7,8'], dtype=object), array(['False,pass,7,8', 'False,receival,8,9', 'False,dribble,8,9',
#        'False,pass,7,8', 'False,receival,7,8'], dtype=object), array(['False,receival,8,9', 'False,dribble,8,9', 'False,pass,7,8',
#        'False,receival,7,8', 'False,dribble,7,8'], dtype=object), array(['False,dribble,8,9', 'False,pass,7,8', 'False,receival,7,8',
#        'False,dribble,7,8', 'False,pass,7,8'], dtype=object), array(['False,pass,7,8', 'False,receival,7,8', 'False,dribble,7,8',
#        'False,pass,7,8', 'False,receival,8,4'], dtype=object), array(['False,receival,7,8', 'False,dribble,7,8', 'False,pass,7,8',
#        'False,receival,8,4', 'False,dribble,8,4'], dtype=object), array(['False,dribble,7,8', 'False,pass,7,8', 'False,receival,8,4',
#        'False,dribble,8,4', 'False,pass,8,4'], dtype=object), array(['False,pass,7,8', 'False,receival,8,4', 'False,dribble,8,4',
#        'False,pass,8,4', 'False,receival,7,3'], dtype=object), array(['False,receival,8,4', 'False,dribble,8,4', 'False,pass,8,4',
#        'False,receival,7,3', 'False,dribble,7,3'], dtype=object), array(['False,dribble,8,4', 'False,pass,8,4', 'False,receival,7,3',
#        'False,dribble,7,3', 'False,pass,7,3'], dtype=object), array(['False,pass,8,4', 'False,receival,7,3', 'False,dribble,7,3',
#        'False,pass,7,3', 'False,receival,8,2'], dtype=object), array(['False,receival,7,3', 'False,dribble,7,3', 'False,pass,7,3',
#        'False,receival,8,2', 'False,dribble,8,2'], dtype=object), array(['False,dribble,7,3', 'False,pass,7,3', 'False,receival,8,2',
#        'False,dribble,8,2', 'False,pass,7,2'], dtype=object), array(['False,pass,7,3', 'False,receival,8,2', 'False,dribble,8,2',
#        'False,pass,7,2', 'False,receival,7,2'], dtype=object), array(['False,receival,8,2', 'False,dribble,8,2', 'False,pass,7,2',
#        'False,receival,7,2', 'False,dribble,7,2'], dtype=object), array(['False,dribble,8,2', 'False,pass,7,2', 'False,receival,7,2',
#        'False,dribble,7,2', 'False,pass,7,1'], dtype=object), array(['False,pass,7,2', 'False,receival,7,2', 'False,dribble,7,2',
#        'False,pass,7,1', 'True,interception,9,3'], dtype=object), array(['False,receival,7,2', 'False,dribble,7,2', 'False,pass,7,1',
#        'True,interception,9,3', 'True,dribble,9,3'], dtype=object), array(['False,dribble,7,2', 'False,pass,7,1', 'True,interception,9,3',
#        'True,dribble,9,3', 'True,pass,8,4'], dtype=object), array(['False,pass,7,1', 'True,interception,9,3', 'True,dribble,9,3',
#        'True,pass,8,4', 'True,receival,8,7'], dtype=object), array(['True,interception,9,3', 'True,dribble,9,3', 'True,pass,8,4',
#        'True,receival,8,7', 'True,dribble,8,7'], dtype=object), array(['True,dribble,9,3', 'True,pass,8,4', 'True,receival,8,7',
#        'True,dribble,8,7', 'True,pass,7,6'], dtype=object), array(['True,pass,8,4', 'True,receival,8,7', 'True,dribble,8,7',
#        'True,pass,7,6', 'True,receival,6,9'], dtype=object), array(['True,receival,8,7', 'True,dribble,8,7', 'True,pass,7,6',
#        'True,receival,6,9', 'True,dribble,6,9'], dtype=object), array(['True,dribble,8,7', 'True,pass,7,6', 'True,receival,6,9',
#        'True,dribble,6,9', 'True,pass,7,9'], dtype=object), array(['True,pass,7,6', 'True,receival,6,9', 'True,dribble,6,9',
#        'True,pass,7,9', 'True,receival,7,8'], dtype=object), array(['True,receival,6,9', 'True,dribble,6,9', 'True,pass,7,9',
#        'True,receival,7,8', 'True,dribble,7,8'], dtype=object), array(['True,dribble,6,9', 'True,pass,7,9', 'True,receival,7,8',
#        'True,dribble,7,8', 'True,pass,7,8'], dtype=object), array(['True,pass,7,9', 'True,receival,7,8', 'True,dribble,7,8',
#        'True,pass,7,8', 'True,receival,9,6'], dtype=object), array(['True,receival,7,8', 'True,dribble,7,8', 'True,pass,7,8',
#        'True,receival,9,6', 'True,dribble,9,6'], dtype=object), array(['True,dribble,7,8', 'True,pass,7,8', 'True,receival,9,6',
#        'True,dribble,9,6', 'True,pass,8,6'], dtype=object), array(['True,pass,7,8', 'True,receival,9,6', 'True,dribble,9,6',
#        'True,pass,8,6', 'True,receival,7,2'], dtype=object), array(['True,receival,9,6', 'True,dribble,9,6', 'True,pass,8,6',
#        'True,receival,7,2', 'True,dribble,7,2'], dtype=object), array(['True,dribble,9,6', 'True,pass,8,6', 'True,receival,7,2',
#        'True,dribble,7,2', 'True,pass,6,2'], dtype=object), array(['True,pass,8,6', 'True,receival,7,2', 'True,dribble,7,2',
#        'True,pass,6,2', 'False,interception,2,1'], dtype=object), array(['True,receival,7,2', 'True,dribble,7,2', 'True,pass,6,2',
#        'False,interception,2,1', 'False,pass,2,1'], dtype=object), array(['True,dribble,7,2', 'True,pass,6,2', 'False,interception,2,1',
#        'False,pass,2,1', 'True,interception,3,1'], dtype=object), array(['True,pass,6,2', 'False,interception,2,1', 'False,pass,2,1',
#        'True,interception,3,1', 'True,pass,3,1'], dtype=object), array(['False,interception,2,1', 'False,pass,2,1',
#        'True,interception,3,1', 'True,pass,3,1', 'True,receival,2,0'],
#       dtype=object), array(['False,pass,2,1', 'True,interception,3,1', 'True,pass,3,1',
#        'True,receival,2,0', 'True,dribble,2,0'], dtype=object), array(['True,interception,3,1', 'True,pass,3,1', 'True,receival,2,0',
#        'True,dribble,2,0', 'True,pass,1,1'], dtype=object), array(['True,pass,3,1', 'True,receival,2,0', 'True,dribble,2,0',
#        'True,pass,1,1', 'True,receival,0,2'], dtype=object), array(['True,receival,2,0', 'True,dribble,2,0', 'True,pass,1,1',
#        'True,receival,0,2', 'True,dribble,0,2'], dtype=object), array(['True,dribble,2,0', 'True,pass,1,1', 'True,receival,0,2',
#        'True,dribble,0,2', 'True,cross,0,2'], dtype=object), array(['True,pass,1,1', 'True,receival,0,2', 'True,dribble,0,2',
#        'True,cross,0,2', 'False,interception,0,4'], dtype=object), array(['True,receival,0,2', 'True,dribble,0,2', 'True,cross,0,2',
#        'False,interception,0,4', 'False,clearance,0,4'], dtype=object), array(['True,dribble,0,2', 'True,cross,0,2', 'False,interception,0,4',
#        'False,clearance,0,4', 'True,interception,1,6'], dtype=object), array(['True,cross,0,2', 'False,interception,0,4', 'False,clearance,0,4',
#        'True,interception,1,6', 'True,pass,1,6'], dtype=object), array(['False,interception,0,4', 'False,clearance,0,4',
#        'True,interception,1,6', 'True,pass,1,6', 'True,receival,2,5'],
#       dtype=object), array(['False,clearance,0,4', 'True,interception,1,6', 'True,pass,1,6',
#        'True,receival,2,5', 'True,dribble,2,5'], dtype=object), array(['True,interception,1,6', 'True,pass,1,6', 'True,receival,2,5',
#        'True,dribble,2,5', 'True,pass,2,5'], dtype=object), array(['True,pass,1,6', 'True,receival,2,5', 'True,dribble,2,5',
#        'True,pass,2,5', 'True,receival,2,3'], dtype=object), array(['True,receival,2,5', 'True,dribble,2,5', 'True,pass,2,5',
#        'True,receival,2,3', 'True,dribble,2,3'], dtype=object), array(['True,dribble,2,5', 'True,pass,2,5', 'True,receival,2,3',
#        'True,dribble,2,3', 'True,pass,2,3'], dtype=object), array(['True,pass,2,5', 'True,receival,2,3', 'True,dribble,2,3',
#        'True,pass,2,3', 'True,receival,1,1'], dtype=object), array(['True,receival,2,3', 'True,dribble,2,3', 'True,pass,2,3',
#        'True,receival,1,1', 'True,dribble,1,1'], dtype=object), array(['True,dribble,2,3', 'True,pass,2,3', 'True,receival,1,1',
#        'True,dribble,1,1', 'True,take_on,1,1'], dtype=object), array(['True,pass,2,3', 'True,receival,1,1', 'True,dribble,1,1',
#        'True,take_on,1,1', 'True,dribble,1,1'], dtype=object), array(['True,receival,1,1', 'True,dribble,1,1', 'True,take_on,1,1',
#        'True,dribble,1,1', 'True,cross,0,2'], dtype=object), array(['True,dribble,1,1', 'True,take_on,1,1', 'True,dribble,1,1',
#        'True,cross,0,2', 'False,interception,0,9'], dtype=object), array(['True,take_on,1,1', 'True,dribble,1,1', 'True,cross,0,2',
#        'False,interception,0,9', 'False,pass,0,9'], dtype=object), array(['True,dribble,1,1', 'True,cross,0,2', 'False,interception,0,9',
#        'False,pass,0,9', 'True,interception,2,9'], dtype=object), array(['True,cross,0,2', 'False,interception,0,9', 'False,pass,0,9',
#        'True,interception,2,9', 'True,dribble,2,9'], dtype=object), array(['False,interception,0,9', 'False,pass,0,9',
#        'True,interception,2,9', 'True,dribble,2,9', 'True,pass,2,8'],
#       dtype=object), array(['False,pass,0,9', 'True,interception,2,9', 'True,dribble,2,9',
#        'True,pass,2,8', 'True,receival,1,6'], dtype=object), array(['True,interception,2,9', 'True,dribble,2,9', 'True,pass,2,8',
#        'True,receival,1,6', 'True,dribble,1,6'], dtype=object), array(['True,dribble,2,9', 'True,pass,2,8', 'True,receival,1,6',
#        'True,dribble,1,6', 'True,pass,2,6'], dtype=object), array(['True,pass,2,8', 'True,receival,1,6', 'True,dribble,1,6',
#        'True,pass,2,6', 'True,receival,2,6'], dtype=object), array(['True,receival,1,6', 'True,dribble,1,6', 'True,pass,2,6',
#        'True,receival,2,6', 'True,dribble,2,6'], dtype=object), array(['True,dribble,1,6', 'True,pass,2,6', 'True,receival,2,6',
#        'True,dribble,2,6', 'True,pass,2,6'], dtype=object), array(['True,pass,2,6', 'True,receival,2,6', 'True,dribble,2,6',
#        'True,pass,2,6', 'True,receival,3,3'], dtype=object), array(['True,receival,2,6', 'True,dribble,2,6', 'True,pass,2,6',
#        'True,receival,3,3', 'True,dribble,3,3'], dtype=object), array(['True,dribble,2,6', 'True,pass,2,6', 'True,receival,3,3',
#        'True,dribble,3,3', 'True,pass,2,3'], dtype=object), array(['True,pass,2,6', 'True,receival,3,3', 'True,dribble,3,3',
#        'True,pass,2,3', 'True,receival,1,5'], dtype=object), array(['True,receival,3,3', 'True,dribble,3,3', 'True,pass,2,3',
#        'True,receival,1,5', 'True,pass,1,6'], dtype=object), array(['True,dribble,3,3', 'True,pass,2,3', 'True,receival,1,5',
#        'True,pass,1,6', 'False,interception,0,4'], dtype=object), array(['True,pass,2,3', 'True,receival,1,5', 'True,pass,1,6',
#        'False,interception,0,4', 'False,clearance,0,4'], dtype=object), array(['True,receival,1,5', 'True,pass,1,6', 'False,interception,0,4',
#        'False,clearance,0,4', 'False,receival,1,6'], dtype=object), array(['True,pass,1,6', 'False,interception,0,4', 'False,clearance,0,4',
#        'False,receival,1,6', 'False,dribble,1,6'], dtype=object), array(['False,interception,0,4', 'False,clearance,0,4',
#        'False,receival,1,6', 'False,dribble,1,6', 'False,pass,2,6'],
#       dtype=object), array(['False,clearance,0,4', 'False,receival,1,6', 'False,dribble,1,6',
#        'False,pass,2,6', 'False,receival,3,4'], dtype=object), array(['False,receival,1,6', 'False,dribble,1,6', 'False,pass,2,6',
#        'False,receival,3,4', 'False,dribble,3,4'], dtype=object), array(['False,dribble,1,6', 'False,pass,2,6', 'False,receival,3,4',
#        'False,dribble,3,4', 'True,tackle,2,5'], dtype=object), array(['False,pass,2,6', 'False,receival,3,4', 'False,dribble,3,4',
#        'True,tackle,2,5', 'False,dribble,2,4'], dtype=object), array(['False,receival,3,4', 'False,dribble,3,4', 'True,tackle,2,5',
#        'False,dribble,2,4', 'False,pass,2,4'], dtype=object), array(['False,dribble,3,4', 'True,tackle,2,5', 'False,dribble,2,4',
#        'False,pass,2,4', 'True,interception,4,2'], dtype=object), array(['True,tackle,2,5', 'False,dribble,2,4', 'False,pass,2,4',
#        'True,interception,4,2', 'True,dribble,4,2'], dtype=object), array(['False,dribble,2,4', 'False,pass,2,4', 'True,interception,4,2',
#        'True,dribble,4,2', 'True,pass,3,2'], dtype=object), array(['False,pass,2,4', 'True,interception,4,2', 'True,dribble,4,2',
#        'True,pass,3,2', 'True,receival,4,2'], dtype=object), array(['True,interception,4,2', 'True,dribble,4,2', 'True,pass,3,2',
#        'True,receival,4,2', 'True,dribble,4,2'], dtype=object), array(['True,dribble,4,2', 'True,pass,3,2', 'True,receival,4,2',
#        'True,dribble,4,2', 'True,pass,4,4'], dtype=object), array(['True,pass,3,2', 'True,receival,4,2', 'True,dribble,4,2',
#        'True,pass,4,4', 'True,receival,5,5'], dtype=object), array(['True,receival,4,2', 'True,dribble,4,2', 'True,pass,4,4',
#        'True,receival,5,5', 'True,dribble,5,5'], dtype=object), array(['True,dribble,4,2', 'True,pass,4,4', 'True,receival,5,5',
#        'True,dribble,5,5', 'True,pass,5,5'], dtype=object), array(['True,pass,4,4', 'True,receival,5,5', 'True,dribble,5,5',
#        'True,pass,5,5', 'True,receival,3,6'], dtype=object), array(['True,receival,5,5', 'True,dribble,5,5', 'True,pass,5,5',
#        'True,receival,3,6', 'True,pass,4,6'], dtype=object), array(['True,dribble,5,5', 'True,pass,5,5', 'True,receival,3,6',
#        'True,pass,4,6', 'True,receival,5,6'], dtype=object), array(['True,pass,5,5', 'True,receival,3,6', 'True,pass,4,6',
#        'True,receival,5,6', 'True,pass,5,6'], dtype=object), array(['True,receival,3,6', 'True,pass,4,6', 'True,receival,5,6',
#        'True,pass,5,6', 'True,receival,3,9'], dtype=object), array(['True,pass,4,6', 'True,receival,5,6', 'True,pass,5,6',
#        'True,receival,3,9', 'True,dribble,3,9'], dtype=object), array(['True,receival,5,6', 'True,pass,5,6', 'True,receival,3,9',
#        'True,dribble,3,9', 'True,pass,4,8'], dtype=object), array(['True,pass,5,6', 'True,receival,3,9', 'True,dribble,3,9',
#        'True,pass,4,8', 'True,receival,6,4'], dtype=object), array(['True,receival,3,9', 'True,dribble,3,9', 'True,pass,4,8',
#        'True,receival,6,4', 'True,dribble,6,4'], dtype=object), array(['True,dribble,3,9', 'True,pass,4,8', 'True,receival,6,4',
#        'True,dribble,6,4', 'True,pass,5,4'], dtype=object), array(['True,pass,4,8', 'True,receival,6,4', 'True,dribble,6,4',
#        'True,pass,5,4', 'True,receival,5,1'], dtype=object), array(['True,receival,6,4', 'True,dribble,6,4', 'True,pass,5,4',
#        'True,receival,5,1', 'True,dribble,5,1'], dtype=object), array(['True,dribble,6,4', 'True,pass,5,4', 'True,receival,5,1',
#        'True,dribble,5,1', 'True,pass,5,1'], dtype=object), array(['True,pass,5,4', 'True,receival,5,1', 'True,dribble,5,1',
#        'True,pass,5,1', 'True,receival,3,2'], dtype=object), array(['True,receival,5,1', 'True,dribble,5,1', 'True,pass,5,1',
#        'True,receival,3,2', 'True,dribble,3,2'], dtype=object), array(['True,dribble,5,1', 'True,pass,5,1', 'True,receival,3,2',
#        'True,dribble,3,2', 'True,pass,3,2'], dtype=object), array(['True,pass,5,1', 'True,receival,3,2', 'True,dribble,3,2',
#        'True,pass,3,2', 'True,receival,5,2'], dtype=object), array(['True,receival,3,2', 'True,dribble,3,2', 'True,pass,3,2',
#        'True,receival,5,2', 'True,dribble,5,2'], dtype=object), array(['True,dribble,3,2', 'True,pass,3,2', 'True,receival,5,2',
#        'True,dribble,5,2', 'True,pass,5,2'], dtype=object), array(['True,pass,3,2', 'True,receival,5,2', 'True,dribble,5,2',
#        'True,pass,5,2', 'True,receival,4,2'], dtype=object), array(['True,receival,5,2', 'True,dribble,5,2', 'True,pass,5,2',
#        'True,receival,4,2', 'True,dribble,4,2'], dtype=object), array(['True,dribble,5,2', 'True,pass,5,2', 'True,receival,4,2',
#        'True,dribble,4,2', 'True,pass,4,2'], dtype=object), array(['True,pass,5,2', 'True,receival,4,2', 'True,dribble,4,2',
#        'True,pass,4,2', 'True,receival,6,8'], dtype=object), array(['True,receival,4,2', 'True,dribble,4,2', 'True,pass,4,2',
#        'True,receival,6,8', 'True,dribble,6,8'], dtype=object), array(['True,dribble,4,2', 'True,pass,4,2', 'True,receival,6,8',
#        'True,dribble,6,8', 'True,pass,5,8'], dtype=object), array(['True,pass,4,2', 'True,receival,6,8', 'True,dribble,6,8',
#        'True,pass,5,8', 'True,receival,7,5'], dtype=object), array(['True,receival,6,8', 'True,dribble,6,8', 'True,pass,5,8',
#        'True,receival,7,5', 'True,dribble,7,5'], dtype=object), array(['True,dribble,6,8', 'True,pass,5,8', 'True,receival,7,5',
#        'True,dribble,7,5', 'True,pass,7,5'], dtype=object), array(['True,pass,5,8', 'True,receival,7,5', 'True,dribble,7,5',
#        'True,pass,7,5', 'True,out,4,9'], dtype=object), array(['True,receival,7,5', 'True,dribble,7,5', 'True,pass,7,5',
#        'True,out,4,9', 'False,throw_in,5,9'], dtype=object), array(['True,dribble,7,5', 'True,pass,7,5', 'True,out,4,9',
#        'False,throw_in,5,9', 'False,receival,5,8'], dtype=object), array(['True,pass,7,5', 'True,out,4,9', 'False,throw_in,5,9',
#        'False,receival,5,8', 'False,dribble,5,8'], dtype=object), array(['True,out,4,9', 'False,throw_in,5,9', 'False,receival,5,8',
#        'False,dribble,5,8', 'False,pass,5,8'], dtype=object), array(['False,throw_in,5,9', 'False,receival,5,8', 'False,dribble,5,8',
#        'False,pass,5,8', 'False,receival,5,9'], dtype=object), array(['False,receival,5,8', 'False,dribble,5,8', 'False,pass,5,8',
#        'False,receival,5,9', 'False,dribble,5,9'], dtype=object), array(['False,dribble,5,8', 'False,pass,5,8', 'False,receival,5,9',
#        'False,dribble,5,9', 'False,pass,5,9'], dtype=object), array(['False,pass,5,8', 'False,receival,5,9', 'False,dribble,5,9',
#        'False,pass,5,9', 'False,receival,6,7'], dtype=object), array(['False,receival,5,9', 'False,dribble,5,9', 'False,pass,5,9',
#        'False,receival,6,7', 'False,dribble,6,7'], dtype=object), array(['False,dribble,5,9', 'False,pass,5,9', 'False,receival,6,7',
#        'False,dribble,6,7', 'False,pass,6,7'], dtype=object), array(['False,pass,5,9', 'False,receival,6,7', 'False,dribble,6,7',
#        'False,pass,6,7', 'False,receival,6,7'], dtype=object), array(['False,receival,6,7', 'False,dribble,6,7', 'False,pass,6,7',
#        'False,receival,6,7', 'False,dribble,6,7'], dtype=object), array(['False,dribble,6,7', 'False,pass,6,7', 'False,receival,6,7',
# ...
#        'False,dribble,5,8', 'False,pass,7,7'], dtype=object), array(['False,pass,4,4', 'False,receival,5,8', 'False,dribble,5,8',
#        'False,pass,7,7', 'False,receival,8,9'], dtype=object), array(['False,receival,5,8', 'False,dribble,5,8', 'False,pass,7,7',
#        'False,receival,8,9', 'False,dribble,8,9'], dtype=object), array(['False,dribble,5,8', 'False,pass,7,7', 'False,receival,8,9',
#        'False,dribble,8,9', 'False,pass,8,8'], dtype=object), array(['False,pass,7,7', 'False,receival,8,9', 'False,dribble,8,9',
#        'False,pass,8,8', 'False,receival,8,8'], dtype=object), array(['False,receival,8,9', 'False,dribble,8,9', 'False,pass,8,8',
#        'False,receival,8,8', 'False,dribble,8,8'], dtype=object), array(['False,dribble,8,9', 'False,pass,8,8', 'False,receival,8,8',
#        'False,dribble,8,8', 'False,pass,8,8'], dtype=object), array(['False,pass,8,8', 'False,receival,8,8', 'False,dribble,8,8',
#        'False,pass,8,8', 'True,interception,9,6'], dtype=object), array(['False,receival,8,8', 'False,dribble,8,8', 'False,pass,8,8',
#        'True,interception,9,6', 'True,dribble,9,6'], dtype=object), array(['False,dribble,8,8', 'False,pass,8,8', 'True,interception,9,6',
#        'True,dribble,9,6', 'True,pass,9,7'], dtype=object), array(['False,pass,8,8', 'True,interception,9,6', 'True,dribble,9,6',
#        'True,pass,9,7', 'True,out,7,9'], dtype=object), array(['True,interception,9,6', 'True,dribble,9,6', 'True,pass,9,7',
#        'True,out,7,9', 'False,throw_in,7,9'], dtype=object), array(['True,dribble,9,6', 'True,pass,9,7', 'True,out,7,9',
#        'False,throw_in,7,9', 'False,receival,7,9'], dtype=object), array(['True,pass,9,7', 'True,out,7,9', 'False,throw_in,7,9',
#        'False,receival,7,9', 'False,dribble,7,9'], dtype=object), array(['True,out,7,9', 'False,throw_in,7,9', 'False,receival,7,9',
#        'False,dribble,7,9', 'False,pass,6,9'], dtype=object), array(['False,throw_in,7,9', 'False,receival,7,9', 'False,dribble,7,9',
#        'False,pass,6,9', 'True,interception,6,9'], dtype=object), array(['False,receival,7,9', 'False,dribble,7,9', 'False,pass,6,9',
#        'True,interception,6,9', 'True,dribble,6,9'], dtype=object), array(['False,dribble,7,9', 'False,pass,6,9', 'True,interception,6,9',
#        'True,dribble,6,9', 'True,pass,5,7'], dtype=object), array(['False,pass,6,9', 'True,interception,6,9', 'True,dribble,6,9',
#        'True,pass,5,7', 'True,receival,3,2'], dtype=object), array(['True,interception,6,9', 'True,dribble,6,9', 'True,pass,5,7',
#        'True,receival,3,2', 'True,dribble,3,2'], dtype=object), array(['True,dribble,6,9', 'True,pass,5,7', 'True,receival,3,2',
#        'True,dribble,3,2', 'True,pass,1,3'], dtype=object), array(['True,pass,5,7', 'True,receival,3,2', 'True,dribble,3,2',
#        'True,pass,1,3', 'True,receival,2,6'], dtype=object), array(['True,receival,3,2', 'True,dribble,3,2', 'True,pass,1,3',
#        'True,receival,2,6', 'True,dribble,2,6'], dtype=object), array(['True,dribble,3,2', 'True,pass,1,3', 'True,receival,2,6',
#        'True,dribble,2,6', 'True,shot,2,6'], dtype=object), array(['True,pass,1,3', 'True,receival,2,6', 'True,dribble,2,6',
#        'True,shot,2,6', 'True,out,0,5'], dtype=object), array(['True,receival,2,6', 'True,dribble,2,6', 'True,shot,2,6',
#        'True,out,0,5', 'False,goalkick,0,4'], dtype=object), array(['True,dribble,2,6', 'True,shot,2,6', 'True,out,0,5',
#        'False,goalkick,0,4', 'True,interception,4,2'], dtype=object), array(['True,shot,2,6', 'True,out,0,5', 'False,goalkick,0,4',
#        'True,interception,4,2', 'True,dribble,4,2'], dtype=object), array(['True,out,0,5', 'False,goalkick,0,4', 'True,interception,4,2',
#        'True,dribble,4,2', 'True,pass,3,2'], dtype=object), array(['False,goalkick,0,4', 'True,interception,4,2', 'True,dribble,4,2',
#        'True,pass,3,2', 'True,receival,1,0'], dtype=object), array(['True,interception,4,2', 'True,dribble,4,2', 'True,pass,3,2',
#        'True,receival,1,0', 'True,dribble,1,0'], dtype=object), array(['True,dribble,4,2', 'True,pass,3,2', 'True,receival,1,0',
#        'True,dribble,1,0', 'True,pass,0,2'], dtype=object), array(['True,pass,3,2', 'True,receival,1,0', 'True,dribble,1,0',
#        'True,pass,0,2', 'True,receival,1,3'], dtype=object), array(['True,receival,1,0', 'True,dribble,1,0', 'True,pass,0,2',
#        'True,receival,1,3', 'True,dribble,1,3'], dtype=object), array(['True,dribble,1,0', 'True,pass,0,2', 'True,receival,1,3',
#        'True,dribble,1,3', 'True,pass,2,4'], dtype=object), array(['True,pass,0,2', 'True,receival,1,3', 'True,dribble,1,3',
#        'True,pass,2,4', 'True,receival,2,6'], dtype=object), array(['True,receival,1,3', 'True,dribble,1,3', 'True,pass,2,4',
#        'True,receival,2,6', 'True,pass,2,6'], dtype=object), array(['True,dribble,1,3', 'True,pass,2,4', 'True,receival,2,6',
#        'True,pass,2,6', 'True,receival,1,8'], dtype=object), array(['True,pass,2,4', 'True,receival,2,6', 'True,pass,2,6',
#        'True,receival,1,8', 'True,dribble,1,8'], dtype=object), array(['True,receival,2,6', 'True,pass,2,6', 'True,receival,1,8',
#        'True,dribble,1,8', 'True,bad_touch,0,7'], dtype=object), array(['True,pass,2,6', 'True,receival,1,8', 'True,dribble,1,8',
#        'True,bad_touch,0,7', 'False,goalkick,0,4'], dtype=object), array(['True,receival,1,8', 'True,dribble,1,8', 'True,bad_touch,0,7',
#        'False,goalkick,0,4', 'False,receival,0,7'], dtype=object), array(['True,dribble,1,8', 'True,bad_touch,0,7', 'False,goalkick,0,4',
#        'False,receival,0,7', 'False,dribble,0,7'], dtype=object), array(['True,bad_touch,0,7', 'False,goalkick,0,4', 'False,receival,0,7',
#        'False,dribble,0,7', 'False,pass,1,8'], dtype=object), array(['False,goalkick,0,4', 'False,receival,0,7', 'False,dribble,0,7',
#        'False,pass,1,8', 'False,receival,5,7'], dtype=object), array(['False,receival,0,7', 'False,dribble,0,7', 'False,pass,1,8',
#        'False,receival,5,7', 'False,dribble,5,7'], dtype=object), array(['False,dribble,0,7', 'False,pass,1,8', 'False,receival,5,7',
#        'False,dribble,5,7', 'False,pass,5,7'], dtype=object), array(['False,pass,1,8', 'False,receival,5,7', 'False,dribble,5,7',
#        'False,pass,5,7', 'True,interception,4,8'], dtype=object), array(['False,receival,5,7', 'False,dribble,5,7', 'False,pass,5,7',
#        'True,interception,4,8', 'True,dribble,4,8'], dtype=object), array(['False,dribble,5,7', 'False,pass,5,7', 'True,interception,4,8',
#        'True,dribble,4,8', 'True,pass,5,8'], dtype=object), array(['False,pass,5,7', 'True,interception,4,8', 'True,dribble,4,8',
#        'True,pass,5,8', 'True,receival,6,6'], dtype=object), array(['True,interception,4,8', 'True,dribble,4,8', 'True,pass,5,8',
#        'True,receival,6,6', 'True,dribble,6,6'], dtype=object), array(['True,dribble,4,8', 'True,pass,5,8', 'True,receival,6,6',
#        'True,dribble,6,6', 'True,pass,6,5'], dtype=object), array(['True,pass,5,8', 'True,receival,6,6', 'True,dribble,6,6',
#        'True,pass,6,5', 'True,receival,6,3'], dtype=object), array(['True,receival,6,6', 'True,dribble,6,6', 'True,pass,6,5',
#        'True,receival,6,3', 'True,dribble,6,3'], dtype=object), array(['True,dribble,6,6', 'True,pass,6,5', 'True,receival,6,3',
#        'True,dribble,6,3', 'True,pass,5,3'], dtype=object), array(['True,pass,6,5', 'True,receival,6,3', 'True,dribble,6,3',
#        'True,pass,5,3', 'True,out,2,9'], dtype=object), array(['True,receival,6,3', 'True,dribble,6,3', 'True,pass,5,3',
#        'True,out,2,9', 'False,throw_in,1,9'], dtype=object), array(['True,dribble,6,3', 'True,pass,5,3', 'True,out,2,9',
#        'False,throw_in,1,9', 'False,receival,0,8'], dtype=object), array(['True,pass,5,3', 'True,out,2,9', 'False,throw_in,1,9',
#        'False,receival,0,8', 'False,dribble,0,8'], dtype=object), array(['True,out,2,9', 'False,throw_in,1,9', 'False,receival,0,8',
#        'False,dribble,0,8', 'False,pass,0,6'], dtype=object), array(['False,throw_in,1,9', 'False,receival,0,8', 'False,dribble,0,8',
#        'False,pass,0,6', 'True,interception,3,2'], dtype=object), array(['False,receival,0,8', 'False,dribble,0,8', 'False,pass,0,6',
#        'True,interception,3,2', 'True,dribble,3,2'], dtype=object), array(['False,dribble,0,8', 'False,pass,0,6', 'True,interception,3,2',
#        'True,dribble,3,2', 'True,pass,3,2'], dtype=object), array(['False,pass,0,6', 'True,interception,3,2', 'True,dribble,3,2',
#        'True,pass,3,2', 'True,receival,3,3'], dtype=object), array(['True,interception,3,2', 'True,dribble,3,2', 'True,pass,3,2',
#        'True,receival,3,3', 'True,dribble,3,3'], dtype=object), array(['True,dribble,3,2', 'True,pass,3,2', 'True,receival,3,3',
#        'True,dribble,3,3', 'True,pass,3,3'], dtype=object), array(['True,pass,3,2', 'True,receival,3,3', 'True,dribble,3,3',
#        'True,pass,3,3', 'True,receival,3,7'], dtype=object), array(['True,receival,3,3', 'True,dribble,3,3', 'True,pass,3,3',
#        'True,receival,3,7', 'True,dribble,3,7'], dtype=object), array(['True,dribble,3,3', 'True,pass,3,3', 'True,receival,3,7',
#        'True,dribble,3,7', 'True,pass,2,6'], dtype=object), array(['True,pass,3,3', 'True,receival,3,7', 'True,dribble,3,7',
#        'True,pass,2,6', 'True,receival,2,7'], dtype=object), array(['True,receival,3,7', 'True,dribble,3,7', 'True,pass,2,6',
#        'True,receival,2,7', 'True,pass,2,7'], dtype=object), array(['True,dribble,3,7', 'True,pass,2,6', 'True,receival,2,7',
#        'True,pass,2,7', 'True,receival,2,8'], dtype=object), array(['True,pass,2,6', 'True,receival,2,7', 'True,pass,2,7',
#        'True,receival,2,8', 'True,dribble,2,8'], dtype=object), array(['True,receival,2,7', 'True,pass,2,7', 'True,receival,2,8',
#        'True,dribble,2,8', 'True,pass,2,8'], dtype=object), array(['True,pass,2,7', 'True,receival,2,8', 'True,dribble,2,8',
#        'True,pass,2,8', 'True,receival,1,7'], dtype=object), array(['True,receival,2,8', 'True,dribble,2,8', 'True,pass,2,8',
#        'True,receival,1,7', 'True,dribble,1,7'], dtype=object), array(['True,dribble,2,8', 'True,pass,2,8', 'True,receival,1,7',
#        'True,dribble,1,7', 'True,pass,1,7'], dtype=object), array(['True,pass,2,8', 'True,receival,1,7', 'True,dribble,1,7',
#        'True,pass,1,7', 'True,receival,2,7'], dtype=object), array(['True,receival,1,7', 'True,dribble,1,7', 'True,pass,1,7',
#        'True,receival,2,7', 'True,dribble,2,7'], dtype=object), array(['True,dribble,1,7', 'True,pass,1,7', 'True,receival,2,7',
#        'True,dribble,2,7', 'True,pass,2,8'], dtype=object), array(['True,pass,1,7', 'True,receival,2,7', 'True,dribble,2,7',
#        'True,pass,2,8', 'True,receival,1,9'], dtype=object), array(['True,receival,2,7', 'True,dribble,2,7', 'True,pass,2,8',
#        'True,receival,1,9', 'True,dribble,1,9'], dtype=object), array(['True,dribble,2,7', 'True,pass,2,8', 'True,receival,1,9',
#        'True,dribble,1,9', 'True,pass,1,9'], dtype=object), array(['True,pass,2,8', 'True,receival,1,9', 'True,dribble,1,9',
#        'True,pass,1,9', 'True,receival,2,9'], dtype=object), array(['True,receival,1,9', 'True,dribble,1,9', 'True,pass,1,9',
#        'True,receival,2,9', 'True,dribble,2,9'], dtype=object), array(['True,dribble,1,9', 'True,pass,1,9', 'True,receival,2,9',
#        'True,dribble,2,9', 'True,pass,2,9'], dtype=object), array(['True,pass,1,9', 'True,receival,2,9', 'True,dribble,2,9',
#        'True,pass,2,9', 'True,receival,2,9'], dtype=object), array(['True,receival,2,9', 'True,dribble,2,9', 'True,pass,2,9',
#        'True,receival,2,9', 'True,pass,2,9'], dtype=object), array(['True,dribble,2,9', 'True,pass,2,9', 'True,receival,2,9',
#        'True,pass,2,9', 'True,receival,2,9'], dtype=object), array(['True,pass,2,9', 'True,receival,2,9', 'True,pass,2,9',
#        'True,receival,2,9', 'True,dribble,2,9'], dtype=object), array(['True,receival,2,9', 'True,pass,2,9', 'True,receival,2,9',
#        'True,dribble,2,9', 'True,pass,2,9'], dtype=object), array(['True,pass,2,9', 'True,receival,2,9', 'True,dribble,2,9',
#        'True,pass,2,9', 'True,receival,2,8'], dtype=object), array(['True,receival,2,9', 'True,dribble,2,9', 'True,pass,2,9',
#        'True,receival,2,8', 'True,dribble,2,8'], dtype=object), array(['True,dribble,2,9', 'True,pass,2,9', 'True,receival,2,8',
#        'True,dribble,2,8', 'True,pass,2,8'], dtype=object), array(['True,pass,2,9', 'True,receival,2,8', 'True,dribble,2,8',
#        'True,pass,2,8', 'True,receival,3,6'], dtype=object), array(['True,receival,2,8', 'True,dribble,2,8', 'True,pass,2,8',
#        'True,receival,3,6', 'True,dribble,3,6'], dtype=object), array(['True,dribble,2,8', 'True,pass,2,8', 'True,receival,3,6',
#        'True,dribble,3,6', 'True,pass,3,6'], dtype=object), array(['True,pass,2,8', 'True,receival,3,6', 'True,dribble,3,6',
#        'True,pass,3,6', 'True,receival,4,4'], dtype=object), array(['True,receival,3,6', 'True,dribble,3,6', 'True,pass,3,6',
#        'True,receival,4,4', 'True,pass,4,4'], dtype=object), array(['True,dribble,3,6', 'True,pass,3,6', 'True,receival,4,4',
#        'True,pass,4,4', 'True,receival,4,7'], dtype=object), array(['True,pass,3,6', 'True,receival,4,4', 'True,pass,4,4',
#        'True,receival,4,7', 'True,dribble,4,7'], dtype=object), array(['True,receival,4,4', 'True,pass,4,4', 'True,receival,4,7',
#        'True,dribble,4,7', 'True,pass,4,8'], dtype=object), array(['True,pass,4,4', 'True,receival,4,7', 'True,dribble,4,7',
#        'True,pass,4,8', 'True,receival,4,9'], dtype=object), array(['True,receival,4,7', 'True,dribble,4,7', 'True,pass,4,8',
#        'True,receival,4,9', 'True,dribble,4,9'], dtype=object), array(['True,dribble,4,7', 'True,pass,4,8', 'True,receival,4,9',
#        'True,dribble,4,9', 'True,pass,3,9'], dtype=object), array(['True,pass,4,8', 'True,receival,4,9', 'True,dribble,4,9',
#        'True,pass,3,9', 'True,receival,4,7'], dtype=object), array(['True,receival,4,9', 'True,dribble,4,9', 'True,pass,3,9',
#        'True,receival,4,7', 'True,dribble,4,7'], dtype=object), array(['True,dribble,4,9', 'True,pass,3,9', 'True,receival,4,7',
#        'True,dribble,4,7', 'True,pass,4,6'], dtype=object), array(['True,pass,3,9', 'True,receival,4,7', 'True,dribble,4,7',
#        'True,pass,4,6', 'True,receival,4,7'], dtype=object), array(['True,receival,4,7', 'True,dribble,4,7', 'True,pass,4,6',
#        'True,receival,4,7', 'True,dribble,4,7'], dtype=object), array(['True,dribble,4,7', 'True,pass,4,6', 'True,receival,4,7',
#        'True,dribble,4,7', 'True,pass,4,7'], dtype=object), array(['True,pass,4,6', 'True,receival,4,7', 'True,dribble,4,7',
#        'True,pass,4,7', 'True,receival,5,3'], dtype=object), array(['True,receival,4,7', 'True,dribble,4,7', 'True,pass,4,7',
#        'True,receival,5,3', 'True,dribble,5,3'], dtype=object), array(['True,dribble,4,7', 'True,pass,4,7', 'True,receival,5,3',
#        'True,dribble,5,3', 'True,pass,4,3'], dtype=object), array(['True,pass,4,7', 'True,receival,5,3', 'True,dribble,5,3',
#        'True,pass,4,3', 'True,receival,1,0'], dtype=object), array(['True,receival,5,3', 'True,dribble,5,3', 'True,pass,4,3',
#        'True,receival,1,0', 'True,dribble,1,0'], dtype=object), array(['True,dribble,5,3', 'True,pass,4,3', 'True,receival,1,0',
#        'True,dribble,1,0', 'True,pass,0,0'], dtype=object), array(['True,pass,4,3', 'True,receival,1,0', 'True,dribble,1,0',
#        'True,pass,0,0', 'True,receival,0,1'], dtype=object), array(['True,receival,1,0', 'True,dribble,1,0', 'True,pass,0,0',
#        'True,receival,0,1', 'True,dribble,0,1'], dtype=object), array(['True,dribble,1,0', 'True,pass,0,0', 'True,receival,0,1',
#        'True,dribble,0,1', 'True,shot,1,3'], dtype=object), array(['True,pass,0,0', 'True,receival,0,1', 'True,dribble,0,1',
#        'True,shot,1,3', 'False,pass,1,6'], dtype=object), array(['True,receival,0,1', 'True,dribble,0,1', 'True,shot,1,3',
#        'False,pass,1,6', 'False,receival,1,5'], dtype=object), array(['True,dribble,0,1', 'True,shot,1,3', 'False,pass,1,6',
#        'False,receival,1,5', 'False,dribble,1,5'], dtype=object), array(['True,shot,1,3', 'False,pass,1,6', 'False,receival,1,5',
#        'False,dribble,1,5', 'False,pass,1,5'], dtype=object)]

# %%
print(len(Xs))
# Out:
# 652

# %%
X = np.concatenate(Xs)
y = np.concatenate(ys)
X.shape, y.shape
# Out:
# ((936660, 5), (936660,))

# %%
torch.save(X, 'X.pt')
torch.save(y, 'y.pt')
